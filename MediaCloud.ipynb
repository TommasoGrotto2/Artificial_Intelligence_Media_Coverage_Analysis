# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade mediacloud
# Out:
# Collecting mediacloud
#   Downloading mediacloud-4.4.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests==2.* in /usr/local/lib/python3.12/dist-packages (from mediacloud) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.*->mediacloud) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.*->mediacloud) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.*->mediacloud) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.*->mediacloud) (2025.8.3)
# Downloading mediacloud-4.4.1-py3-none-any.whl (24 kB)
# Installing collected packages: mediacloud
# Successfully installed mediacloud-4.4.1

# %%
import logging
import datetime
import csv
import sys
import time
import mediacloud.api
import shutil  # for file copying

# ----------------------------------------------------------------------------
# CONFIGURATION
# ----------------------------------------------------------------------------

API_KEY = "0204d14c4f0a2d0f2a73238a48baafeeed105b5d"

# 1) Search Keywords (list of strings to simulate complex queries)
SEARCH_KEYWORDS = [
    #"artificial intelligence",
    #"intelligenza artificiale",
    #"künstliche Intelligenz",
    #"intelligence artificielle",
    #"人工知能",
    #"人工智能", #semplified
    "人工智慧", #traditional
]

# 2) Location (for reference in naming)
SEARCH_LOCATION = "china"

# 3) Overall Time Range
START_DATE_STR = "2024-06-01"
END_DATE_STR   = "2025-06-01"

# 4) Collection IDs for the given location
COLLECTION_IDS = [
    #34412234, # United States - National
    #38379429, # United States - State & Local
    #34412372, # Italy - National
    #38380117, # Italy - State & Local
    #34412409, # Germany - National
    #38379816, # Germany - State & Local
    #34412146, # France - National
    #38379799, # France - State & Local
    34412193, # China - National
    38379438, # China - State & Local
    #34412056, # Japan - National
    #38380157, # Japan - State & Local
]



#34412476, # United Kingdom - National
    #38381111, # United Kingdom - State & Local

# United Kingdom - National
# https://search.mediacloud.org/collections/34412476

# United Kingdom - State & Local
# https://search.mediacloud.org/collections/38381111



# 5) Google Drive folder path
GDRIVE_PATH = "/content/drive/MyDrive/Mediacloud/China"

# Final CSV filename (for the entire range) with "mediacloud" in the name
FINAL_CSV_FILENAME = (
    f"{SEARCH_KEYWORDS[0].lower().replace(' ', '_')}_"
    f"{SEARCH_LOCATION.lower()}_"
    f"{START_DATE_STR}_{END_DATE_STR}_mediacloud.csv"
)

# ----------------------------------------------------------------------------
# LOGGING SETUP
# ----------------------------------------------------------------------------

logging.basicConfig(
    stream=sys.stdout,
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# ----------------------------------------------------------------------------
# HELPER FUNCTIONS
# ----------------------------------------------------------------------------

def parse_date(date_str):
    """
    Convert 'YYYY-MM-DD' string to datetime.date.
    Raises ValueError if not correctly formatted.
    """
    return datetime.datetime.strptime(date_str, "%Y-%m-%d").date()

def last_day_of_month(any_date):
    """
    Given a datetime.date, return a date object representing
    the last day of that same month.
    """
    next_month = any_date.replace(day=28) + datetime.timedelta(days=4)
    return next_month - datetime.timedelta(days=next_month.day)

def generate_monthly_date_ranges(start_date_str, end_date_str):
    """
    Generate a list of (month_start_date, month_end_date) tuples
    covering each month from start_date to end_date inclusive.
    """
    start = parse_date(start_date_str)
    end = parse_date(end_date_str)

    monthly_chunks = []
    current_start = start

    while current_start <= end:
        # Last day of current_start's month
        current_end = last_day_of_month(current_start)
        # Do not exceed the overall end date
        if current_end > end:
            current_end = end

        monthly_chunks.append((current_start, current_end))

        # Move to the day after current_end
        next_month_start = current_end + datetime.timedelta(days=1)
        if next_month_start > end:
            break
        current_start = next_month_start

    return monthly_chunks

def generate_daily_date_ranges(start_date, end_date):
    """
    Generate a list of (day_start, day_end) tuples for each day between
    start_date and end_date (inclusive).
    In this case, day_start == day_end for daily intervals.
    """
    current_start = start_date
    daily_chunks = []

    while current_start <= end_date:
        # For a daily chunk, the start and end are the same date
        chunk_end = current_start
        daily_chunks.append((current_start, chunk_end))
        current_start = current_start + datetime.timedelta(days=1)

    return daily_chunks

def fetch_stories(mc_client, query, start_date, end_date, collection_ids):
    """
    Fetch all stories matching 'query' from 'start_date' to 'end_date' (inclusive),
    within any of the specified collection_ids.

    If more than 1000 stories are found for that day, it will fetch multiple pages,
    sleeping 55s between pages to respect rate limits. Returns a list of story dictionaries.
    """
    all_stories = []
    pagination_token = None

    while True:
        try:
            # Request up to 1000 stories per page
            page_stories, next_token = mc_client.story_list(
                query=query,
                start_date=start_date,
                end_date=end_date,
                collection_ids=collection_ids,
                pagination_token=pagination_token,
                page_size=1000
            )

            # Attach collection_ids to each story for reference
            for story in page_stories:
                story["collection_ids"] = collection_ids

            all_stories.extend(page_stories)

            # Print/log how many articles just fetched, total so far
            logging.info(
                f"Fetched {len(page_stories)} stories in this page; "
                f"{len(all_stories)} total so far (range {start_date} - {end_date})."
            )
            print(
                f"Fetched {len(page_stories)} stories in this request; "
                f"{len(all_stories)} total so far (range {start_date} - {end_date})."
            )

            # If there are no more pages, break
            if next_token is None:
                break

            # Pause for 55 seconds before fetching next page to respect rate limits
            logging.info("Pausing for 55 seconds to respect rate limits (multi-page).")
            print("Pausing for 55 seconds to respect rate limits (multi-page)...")
            time.sleep(55)

            # Prepare for next iteration
            pagination_token = next_token

        except Exception as e:
            logging.error(f"Error during API fetch (range {start_date} - {end_date}): {e}")
            break

    return all_stories

def save_stories_to_csv(stories, filename, query):
    """
    Save the story data to a CSV file, including a 'collection_ids' column and the 'query'.
    """
    fieldnames = [
        "stories_id",
        "title",
        "publish_date",
        "url",
        "language",
        "media_id",
        "media_name",
        "query",
        "collection_ids"
    ]

    try:
        with open(filename, mode="w", newline="", encoding="utf-8") as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()

            for story in stories:
                # Include the query in each row
                story["query"] = query
                row_data = {field: story.get(field, "") for field in fieldnames}
                writer.writerow(row_data)

        logging.info(f"Successfully wrote {len(stories)} stories to {filename}.")
    except Exception as e:
        logging.error(f"Error writing to CSV '{filename}': {e}")

def copy_to_drive(filename, destination_folder):
    """
    Attempt to copy the file from Colab's /content/ to the given Google Drive folder.
    """
    colab_path = f"/content/{filename}"
    try:
        shutil.copy(colab_path, destination_folder)
        logging.info(f"File '{filename}' copied to Google Drive at '{destination_folder}'.")
    except Exception as e:
        logging.error(f"Could not copy file '{filename}' to Google Drive: {e}")

# ----------------------------------------------------------------------------
# MAIN EXECUTION LOGIC
# ----------------------------------------------------------------------------

def main():
    mc_client = mediacloud.api.SearchApi(API_KEY)

    try:
        mc_client.story_list(query="test", start_date=parse_date(START_DATE_STR), end_date=parse_date(START_DATE_STR), page_size=1)
        logging.info("MediaCloud API connection successful.")
    except Exception as e:
        logging.error(f"Could not validate MediaCloud API connection: {e}")
        return

    all_stories = []

    for keyword in SEARCH_KEYWORDS:
        logging.info(f"Starting query: {keyword}")
        monthly_chunks = generate_monthly_date_ranges(START_DATE_STR, END_DATE_STR)

        query_stories = []

        for (month_start, month_end) in monthly_chunks:
            logging.info(f"Processing month {month_start} to {month_end} for query: {keyword}")
            daily_chunks = generate_daily_date_ranges(month_start, month_end)

            for (day_start, day_end) in daily_chunks:
                logging.info(f"  Fetching stories for {day_start} (one-day range)...")
                chunk_stories = fetch_stories(mc_client, keyword, day_start, day_end, COLLECTION_IDS)
                query_stories.extend(chunk_stories)
                logging.info(f"Pausing 55 seconds at the end of day {day_start}.")
                time.sleep(55)

        # Save each query’s results to a temporary CSV
        query_label = keyword.lower().replace(" ", "_").replace('"', "").replace("AND", "and")
        query_csv_filename = f"{query_label}_{SEARCH_LOCATION.lower()}_{START_DATE_STR}_{END_DATE_STR}_mediacloud.csv"
        save_stories_to_csv(query_stories, query_csv_filename, keyword)
        copy_to_drive(query_csv_filename, GDRIVE_PATH)

        all_stories.extend(query_stories)

    # Save combined file
    logging.info(f"Saving final combined CSV for all queries...")
    save_stories_to_csv(all_stories, FINAL_CSV_FILENAME, "; ".join(SEARCH_KEYWORDS))
    copy_to_drive(FINAL_CSV_FILENAME, GDRIVE_PATH)

    logging.info(f"Done! Retrieved {len(all_stories)} total stories from {START_DATE_STR} to {END_DATE_STR}.")


# ----------------------------------------------------------------------------
# RUN
# ----------------------------------------------------------------------------

if __name__ == "__main__":
    main()
# Out:
# Fetched 8 stories in this request; 8 total so far (range 2024-06-01 - 2024-06-01).
# Fetched 4 stories in this request; 4 total so far (range 2024-06-02 - 2024-06-02).
# Fetched 9 stories in this request; 9 total so far (range 2024-06-03 - 2024-06-03).
# Fetched 2 stories in this request; 2 total so far (range 2024-06-04 - 2024-06-04).
# Fetched 5 stories in this request; 5 total so far (range 2024-06-05 - 2024-06-05).
# Fetched 8 stories in this request; 8 total so far (range 2024-06-06 - 2024-06-06).
# Fetched 6 stories in this request; 6 total so far (range 2024-06-07 - 2024-06-07).
# Fetched 6 stories in this request; 6 total so far (range 2024-06-08 - 2024-06-08).
# Fetched 2 stories in this request; 2 total so far (range 2024-06-09 - 2024-06-09).
# Fetched 4 stories in this request; 4 total so far (range 2024-06-10 - 2024-06-10).
# Fetched 7 stories in this request; 7 total so far (range 2024-06-11 - 2024-06-11).
# Fetched 5 stories in this request; 5 total so far (range 2024-06-12 - 2024-06-12).
# Fetched 7 stories in this request; 7 total so far (range 2024-06-13 - 2024-06-13).
# Fetched 5 stories in this request; 5 total so far (range 2024-06-14 - 2024-06-14).
# Fetched 2 stories in this request; 2 total so far (range 2024-06-15 - 2024-06-15).
# Fetched 4 stories in this request; 4 total so far (range 2024-06-16 - 2024-06-16).
# Fetched 4 stories in this request; 4 total so far (range 2024-06-17 - 2024-06-17).
# Fetched 3 stories in this request; 3 total so far (range 2024-06-18 - 2024-06-18).
# Fetched 5 stories in this request; 5 total so far (range 2024-06-19 - 2024-06-19).
# Fetched 4 stories in this request; 4 total so far (range 2024-06-20 - 2024-06-20).
# Fetched 5 stories in this request; 5 total so far (range 2024-06-21 - 2024-06-21).
# Fetched 2 stories in this request; 2 total so far (range 2024-06-22 - 2024-06-22).
# Fetched 6 stories in this request; 6 total so far (range 2024-06-23 - 2024-06-23).
# Fetched 4 stories in this request; 4 total so far (range 2024-06-24 - 2024-06-24).
# Fetched 9 stories in this request; 9 total so far (range 2024-06-25 - 2024-06-25).
# Fetched 17 stories in this request; 17 total so far (range 2024-06-26 - 2024-06-26).
# Fetched 8 stories in this request; 8 total so far (range 2024-06-27 - 2024-06-27).
# Fetched 12 stories in this request; 12 total so far (range 2024-06-28 - 2024-06-28).
# Fetched 6 stories in this request; 6 total so far (range 2024-06-29 - 2024-06-29).
# Fetched 8 stories in this request; 8 total so far (range 2024-06-30 - 2024-06-30).
# Fetched 4 stories in this request; 4 total so far (range 2024-07-01 - 2024-07-01).
# Fetched 4 stories in this request; 4 total so far (range 2024-07-02 - 2024-07-02).
# Fetched 10 stories in this request; 10 total so far (range 2024-07-03 - 2024-07-03).
# Fetched 2 stories in this request; 2 total so far (range 2024-07-04 - 2024-07-04).
# Fetched 5 stories in this request; 5 total so far (range 2024-07-05 - 2024-07-05).
# Fetched 4 stories in this request; 4 total so far (range 2024-07-06 - 2024-07-06).
# Fetched 0 stories in this request; 0 total so far (range 2024-07-07 - 2024-07-07).
# Fetched 6 stories in this request; 6 total so far (range 2024-07-08 - 2024-07-08).
# Fetched 7 stories in this request; 7 total so far (range 2024-07-09 - 2024-07-09).
# Fetched 5 stories in this request; 5 total so far (range 2024-07-10 - 2024-07-10).
# Fetched 9 stories in this request; 9 total so far (range 2024-07-11 - 2024-07-11).
# Fetched 3 stories in this request; 3 total so far (range 2024-07-12 - 2024-07-12).
# Fetched 7 stories in this request; 7 total so far (range 2024-07-13 - 2024-07-13).
# Fetched 7 stories in this request; 7 total so far (range 2024-07-14 - 2024-07-14).
# Fetched 6 stories in this request; 6 total so far (range 2024-07-15 - 2024-07-15).
# Fetched 7 stories in this request; 7 total so far (range 2024-07-16 - 2024-07-16).
# Fetched 5 stories in this request; 5 total so far (range 2024-07-17 - 2024-07-17).
# Fetched 4 stories in this request; 4 total so far (range 2024-07-18 - 2024-07-18).
# Fetched 7 stories in this request; 7 total so far (range 2024-07-19 - 2024-07-19).
# Fetched 1 stories in this request; 1 total so far (range 2024-07-20 - 2024-07-20).
# Fetched 4 stories in this request; 4 total so far (range 2024-07-21 - 2024-07-21).
# Fetched 8 stories in this request; 8 total so far (range 2024-07-22 - 2024-07-22).
# Fetched 3 stories in this request; 3 total so far (range 2024-07-23 - 2024-07-23).
# Fetched 5 stories in this request; 5 total so far (range 2024-07-24 - 2024-07-24).
# Fetched 4 stories in this request; 4 total so far (range 2024-07-25 - 2024-07-25).
# Fetched 5 stories in this request; 5 total so far (range 2024-07-26 - 2024-07-26).
# Fetched 2 stories in this request; 2 total so far (range 2024-07-27 - 2024-07-27).
# Fetched 3 stories in this request; 3 total so far (range 2024-07-28 - 2024-07-28).
# Fetched 8 stories in this request; 8 total so far (range 2024-07-29 - 2024-07-29).
# Fetched 3 stories in this request; 3 total so far (range 2024-07-30 - 2024-07-30).
# Fetched 5 stories in this request; 5 total so far (range 2024-07-31 - 2024-07-31).
# Fetched 6 stories in this request; 6 total so far (range 2024-08-01 - 2024-08-01).
# Fetched 6 stories in this request; 6 total so far (range 2024-08-02 - 2024-08-02).
# Fetched 2 stories in this request; 2 total so far (range 2024-08-03 - 2024-08-03).
# Fetched 2 stories in this request; 2 total so far (range 2024-08-04 - 2024-08-04).
# Fetched 9 stories in this request; 9 total so far (range 2024-08-05 - 2024-08-05).
# Fetched 7 stories in this request; 7 total so far (range 2024-08-06 - 2024-08-06).
# Fetched 11 stories in this request; 11 total so far (range 2024-08-07 - 2024-08-07).
# Fetched 7 stories in this request; 7 total so far (range 2024-08-08 - 2024-08-08).
# Fetched 4 stories in this request; 4 total so far (range 2024-08-09 - 2024-08-09).
# Fetched 2 stories in this request; 2 total so far (range 2024-08-10 - 2024-08-10).
# Fetched 2 stories in this request; 2 total so far (range 2024-08-11 - 2024-08-11).
# Fetched 6 stories in this request; 6 total so far (range 2024-08-12 - 2024-08-12).
# Fetched 3 stories in this request; 3 total so far (range 2024-08-13 - 2024-08-13).
# Fetched 2 stories in this request; 2 total so far (range 2024-08-14 - 2024-08-14).
# Fetched 12 stories in this request; 12 total so far (range 2024-08-15 - 2024-08-15).
# Fetched 5 stories in this request; 5 total so far (range 2024-08-16 - 2024-08-16).
# Fetched 1 stories in this request; 1 total so far (range 2024-08-17 - 2024-08-17).
# Fetched 3 stories in this request; 3 total so far (range 2024-08-18 - 2024-08-18).
# Fetched 8 stories in this request; 8 total so far (range 2024-08-19 - 2024-08-19).
# Fetched 9 stories in this request; 9 total so far (range 2024-08-20 - 2024-08-20).
# Fetched 8 stories in this request; 8 total so far (range 2024-08-21 - 2024-08-21).
# Fetched 7 stories in this request; 7 total so far (range 2024-08-22 - 2024-08-22).
# Fetched 2 stories in this request; 2 total so far (range 2024-08-23 - 2024-08-23).
# Fetched 5 stories in this request; 5 total so far (range 2024-08-24 - 2024-08-24).
# Fetched 3 stories in this request; 3 total so far (range 2024-08-25 - 2024-08-25).
# Fetched 7 stories in this request; 7 total so far (range 2024-08-26 - 2024-08-26).
# Fetched 7 stories in this request; 7 total so far (range 2024-08-27 - 2024-08-27).
# Fetched 12 stories in this request; 12 total so far (range 2024-08-28 - 2024-08-28).
# Fetched 17 stories in this request; 17 total so far (range 2024-08-29 - 2024-08-29).
# Fetched 6 stories in this request; 6 total so far (range 2024-08-30 - 2024-08-30).
# Fetched 4 stories in this request; 4 total so far (range 2024-08-31 - 2024-08-31).
# Fetched 3 stories in this request; 3 total so far (range 2024-09-01 - 2024-09-01).
# Fetched 4 stories in this request; 4 total so far (range 2024-09-02 - 2024-09-02).
# Fetched 5 stories in this request; 5 total so far (range 2024-09-03 - 2024-09-03).
# Fetched 2 stories in this request; 2 total so far (range 2024-09-04 - 2024-09-04).
# Fetched 8 stories in this request; 8 total so far (range 2024-09-05 - 2024-09-05).
# Fetched 6 stories in this request; 6 total so far (range 2024-09-06 - 2024-09-06).
# Fetched 1 stories in this request; 1 total so far (range 2024-09-07 - 2024-09-07).
# Fetched 8 stories in this request; 8 total so far (range 2024-09-08 - 2024-09-08).
# Fetched 8 stories in this request; 8 total so far (range 2024-09-09 - 2024-09-09).
# Fetched 6 stories in this request; 6 total so far (range 2024-09-10 - 2024-09-10).
# Fetched 8 stories in this request; 8 total so far (range 2024-09-11 - 2024-09-11).
# Fetched 7 stories in this request; 7 total so far (range 2024-09-12 - 2024-09-12).
# Fetched 11 stories in this request; 11 total so far (range 2024-09-13 - 2024-09-13).
# Fetched 7 stories in this request; 7 total so far (range 2024-09-14 - 2024-09-14).
# Fetched 9 stories in this request; 9 total so far (range 2024-09-15 - 2024-09-15).
# Fetched 5 stories in this request; 5 total so far (range 2024-09-16 - 2024-09-16).
# Fetched 2 stories in this request; 2 total so far (range 2024-09-17 - 2024-09-17).
# Fetched 1 stories in this request; 1 total so far (range 2024-09-18 - 2024-09-18).
# Fetched 7 stories in this request; 7 total so far (range 2024-09-19 - 2024-09-19).
# Fetched 7 stories in this request; 7 total so far (range 2024-09-20 - 2024-09-20).
# Fetched 6 stories in this request; 6 total so far (range 2024-09-21 - 2024-09-21).
# Fetched 3 stories in this request; 3 total so far (range 2024-09-22 - 2024-09-22).
# Fetched 4 stories in this request; 4 total so far (range 2024-09-23 - 2024-09-23).
# Fetched 7 stories in this request; 7 total so far (range 2024-09-24 - 2024-09-24).
# Fetched 7 stories in this request; 7 total so far (range 2024-09-25 - 2024-09-25).
# Fetched 3 stories in this request; 3 total so far (range 2024-09-26 - 2024-09-26).
# Fetched 9 stories in this request; 9 total so far (range 2024-09-27 - 2024-09-27).
# Fetched 6 stories in this request; 6 total so far (range 2024-09-28 - 2024-09-28).
# Fetched 6 stories in this request; 6 total so far (range 2024-09-29 - 2024-09-29).
# Fetched 5 stories in this request; 5 total so far (range 2024-09-30 - 2024-09-30).
# Fetched 6 stories in this request; 6 total so far (range 2024-10-01 - 2024-10-01).
# Fetched 1 stories in this request; 1 total so far (range 2024-10-02 - 2024-10-02).
# Fetched 2 stories in this request; 2 total so far (range 2024-10-03 - 2024-10-03).
# Fetched 2 stories in this request; 2 total so far (range 2024-10-04 - 2024-10-04).
# Fetched 3 stories in this request; 3 total so far (range 2024-10-05 - 2024-10-05).
# Fetched 1 stories in this request; 1 total so far (range 2024-10-06 - 2024-10-06).
# Fetched 4 stories in this request; 4 total so far (range 2024-10-07 - 2024-10-07).
# Fetched 4 stories in this request; 4 total so far (range 2024-10-08 - 2024-10-08).
# Fetched 7 stories in this request; 7 total so far (range 2024-10-09 - 2024-10-09).
# Fetched 6 stories in this request; 6 total so far (range 2024-10-10 - 2024-10-10).
# Fetched 1 stories in this request; 1 total so far (range 2024-10-11 - 2024-10-11).
# Fetched 5 stories in this request; 5 total so far (range 2024-10-12 - 2024-10-12).
# Fetched 2 stories in this request; 2 total so far (range 2024-10-13 - 2024-10-13).
# Fetched 2 stories in this request; 2 total so far (range 2024-10-14 - 2024-10-14).
# Fetched 4 stories in this request; 4 total so far (range 2024-10-15 - 2024-10-15).
# Fetched 2 stories in this request; 2 total so far (range 2024-10-16 - 2024-10-16).
# Fetched 4 stories in this request; 4 total so far (range 2024-10-17 - 2024-10-17).
# Fetched 7 stories in this request; 7 total so far (range 2024-10-18 - 2024-10-18).
# Fetched 3 stories in this request; 3 total so far (range 2024-10-19 - 2024-10-19).
# Fetched 6 stories in this request; 6 total so far (range 2024-10-20 - 2024-10-20).
# Fetched 5 stories in this request; 5 total so far (range 2024-10-21 - 2024-10-21).
# Fetched 3 stories in this request; 3 total so far (range 2024-10-22 - 2024-10-22).
# Fetched 2 stories in this request; 2 total so far (range 2024-10-23 - 2024-10-23).
# Fetched 6 stories in this request; 6 total so far (range 2024-10-24 - 2024-10-24).
# Fetched 8 stories in this request; 8 total so far (range 2024-10-25 - 2024-10-25).
# Fetched 6 stories in this request; 6 total so far (range 2024-10-26 - 2024-10-26).
# Fetched 2 stories in this request; 2 total so far (range 2024-10-27 - 2024-10-27).
# Fetched 4 stories in this request; 4 total so far (range 2024-10-28 - 2024-10-28).
# Fetched 6 stories in this request; 6 total so far (range 2024-10-29 - 2024-10-29).
# Fetched 4 stories in this request; 4 total so far (range 2024-10-30 - 2024-10-30).
# Fetched 6 stories in this request; 6 total so far (range 2024-10-31 - 2024-10-31).
# Fetched 7 stories in this request; 7 total so far (range 2024-11-01 - 2024-11-01).
# Fetched 4 stories in this request; 4 total so far (range 2024-11-02 - 2024-11-02).
# Fetched 7 stories in this request; 7 total so far (range 2024-11-03 - 2024-11-03).
# Fetched 4 stories in this request; 4 total so far (range 2024-11-04 - 2024-11-04).
# Fetched 4 stories in this request; 4 total so far (range 2024-11-05 - 2024-11-05).
# Fetched 3 stories in this request; 3 total so far (range 2024-11-06 - 2024-11-06).
# Fetched 11 stories in this request; 11 total so far (range 2024-11-07 - 2024-11-07).
# Fetched 13 stories in this request; 13 total so far (range 2024-11-08 - 2024-11-08).
# Fetched 2 stories in this request; 2 total so far (range 2024-11-09 - 2024-11-09).
# Fetched 4 stories in this request; 4 total so far (range 2024-11-10 - 2024-11-10).
# Fetched 4 stories in this request; 4 total so far (range 2024-11-11 - 2024-11-11).
# Fetched 7 stories in this request; 7 total so far (range 2024-11-12 - 2024-11-12).
# Fetched 10 stories in this request; 10 total so far (range 2024-11-13 - 2024-11-13).
# Fetched 12 stories in this request; 12 total so far (range 2024-11-14 - 2024-11-14).
# Fetched 15 stories in this request; 15 total so far (range 2024-11-15 - 2024-11-15).
# Fetched 6 stories in this request; 6 total so far (range 2024-11-16 - 2024-11-16).
# Fetched 5 stories in this request; 5 total so far (range 2024-11-17 - 2024-11-17).
# Fetched 8 stories in this request; 8 total so far (range 2024-11-18 - 2024-11-18).
# Fetched 9 stories in this request; 9 total so far (range 2024-11-19 - 2024-11-19).
# Fetched 5 stories in this request; 5 total so far (range 2024-11-20 - 2024-11-20).
# Fetched 8 stories in this request; 8 total so far (range 2024-11-21 - 2024-11-21).
# Fetched 5 stories in this request; 5 total so far (range 2024-11-22 - 2024-11-22).
# Fetched 5 stories in this request; 5 total so far (range 2024-11-23 - 2024-11-23).
# Fetched 4 stories in this request; 4 total so far (range 2024-11-24 - 2024-11-24).
# Fetched 3 stories in this request; 3 total so far (range 2024-11-25 - 2024-11-25).
# Fetched 6 stories in this request; 6 total so far (range 2024-11-26 - 2024-11-26).
# Fetched 7 stories in this request; 7 total so far (range 2024-11-27 - 2024-11-27).
# Fetched 6 stories in this request; 6 total so far (range 2024-11-28 - 2024-11-28).
# Fetched 12 stories in this request; 12 total so far (range 2024-11-29 - 2024-11-29).
# Fetched 5 stories in this request; 5 total so far (range 2024-11-30 - 2024-11-30).
# Fetched 4 stories in this request; 4 total so far (range 2024-12-01 - 2024-12-01).
# Fetched 1 stories in this request; 1 total so far (range 2024-12-02 - 2024-12-02).
# Fetched 3 stories in this request; 3 total so far (range 2024-12-03 - 2024-12-03).
# Fetched 4 stories in this request; 4 total so far (range 2024-12-04 - 2024-12-04).
# Fetched 2 stories in this request; 2 total so far (range 2024-12-05 - 2024-12-05).
# Fetched 8 stories in this request; 8 total so far (range 2024-12-06 - 2024-12-06).
# Fetched 1 stories in this request; 1 total so far (range 2024-12-07 - 2024-12-07).
# Fetched 2 stories in this request; 2 total so far (range 2024-12-08 - 2024-12-08).
# Fetched 5 stories in this request; 5 total so far (range 2024-12-09 - 2024-12-09).
# Fetched 5 stories in this request; 5 total so far (range 2024-12-10 - 2024-12-10).
# Fetched 5 stories in this request; 5 total so far (range 2024-12-11 - 2024-12-11).
# Fetched 2 stories in this request; 2 total so far (range 2024-12-12 - 2024-12-12).
# Fetched 6 stories in this request; 6 total so far (range 2024-12-13 - 2024-12-13).
# Fetched 6 stories in this request; 6 total so far (range 2024-12-14 - 2024-12-14).
# Fetched 9 stories in this request; 9 total so far (range 2024-12-15 - 2024-12-15).
# Fetched 11 stories in this request; 11 total so far (range 2024-12-16 - 2024-12-16).
# Fetched 3 stories in this request; 3 total so far (range 2024-12-17 - 2024-12-17).
# Fetched 5 stories in this request; 5 total so far (range 2024-12-18 - 2024-12-18).
# Fetched 4 stories in this request; 4 total so far (range 2024-12-19 - 2024-12-19).
# Fetched 6 stories in this request; 6 total so far (range 2024-12-20 - 2024-12-20).
# Fetched 4 stories in this request; 4 total so far (range 2024-12-21 - 2024-12-21).
# Fetched 6 stories in this request; 6 total so far (range 2024-12-22 - 2024-12-22).
# Fetched 4 stories in this request; 4 total so far (range 2024-12-23 - 2024-12-23).
# Fetched 0 stories in this request; 0 total so far (range 2024-12-24 - 2024-12-24).
# Fetched 2 stories in this request; 2 total so far (range 2024-12-25 - 2024-12-25).
# Fetched 3 stories in this request; 3 total so far (range 2024-12-26 - 2024-12-26).
# Fetched 3 stories in this request; 3 total so far (range 2024-12-27 - 2024-12-27).
# Fetched 3 stories in this request; 3 total so far (range 2024-12-28 - 2024-12-28).
# Fetched 3 stories in this request; 3 total so far (range 2024-12-29 - 2024-12-29).
# Fetched 3 stories in this request; 3 total so far (range 2024-12-30 - 2024-12-30).
# Fetched 9 stories in this request; 9 total so far (range 2024-12-31 - 2024-12-31).
# Fetched 6 stories in this request; 6 total so far (range 2025-01-01 - 2025-01-01).
# Fetched 4 stories in this request; 4 total so far (range 2025-01-02 - 2025-01-02).
# Fetched 5 stories in this request; 5 total so far (range 2025-01-03 - 2025-01-03).
# Fetched 4 stories in this request; 4 total so far (range 2025-01-04 - 2025-01-04).
# Fetched 3 stories in this request; 3 total so far (range 2025-01-05 - 2025-01-05).
# Fetched 5 stories in this request; 5 total so far (range 2025-01-06 - 2025-01-06).
# Fetched 4 stories in this request; 4 total so far (range 2025-01-07 - 2025-01-07).
# Fetched 3 stories in this request; 3 total so far (range 2025-01-08 - 2025-01-08).
# Fetched 3 stories in this request; 3 total so far (range 2025-01-09 - 2025-01-09).
# Fetched 6 stories in this request; 6 total so far (range 2025-01-10 - 2025-01-10).
# Fetched 1 stories in this request; 1 total so far (range 2025-01-11 - 2025-01-11).
# Fetched 3 stories in this request; 3 total so far (range 2025-01-12 - 2025-01-12).
# Fetched 3 stories in this request; 3 total so far (range 2025-01-13 - 2025-01-13).
# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Mediacloud/China/人工智慧_traditional_china_2024-06-01_2025-06-01_mediacloud.csv')
df.head()
# Out:
#    stories_id                              title publish_date  \
# 0         NaN                心相近｜共谱发展新篇 续写“中阿情缘”   2024-06-01
# 1         NaN               《中华优秀传统文化少儿绘本大系》在京首发   2024-06-01
# 2         NaN             共产党进城后，从城市管理到城市治理的转型发展   2024-06-01
# 3         NaN          开放提速 创新潮涌——来自第十三届中部博览会的观察   2024-06-01
# 4         NaN  赓续中华文脉 厚植文化自信——写在文化传承发展座谈会召开一周年之际   2024-06-01
#
#                                                  url language  media_id  \
# 0           http://www.81.cn/xx_207779/16313075.html       zh       NaN
# 1  http://www.81.cn/yd_208600/jdt_208601/16313633...       zh       NaN
# 2           http://www.81.cn/yd_208600/16313591.html       zh       NaN
# 3           http://www.81.cn/ss_208539/16313160.html       zh       NaN
# 4           http://www.81.cn/yw_208727/16313143.html       zh       NaN
#
#   media_name query        collection_ids
# 0      81.cn  人工智慧  [34412193, 38379438]
# 1      81.cn  人工智慧  [34412193, 38379438]
# 2      81.cn  人工智慧  [34412193, 38379438]
# 3      81.cn  人工智慧  [34412193, 38379438]
# 4      81.cn  人工智慧  [34412193, 38379438]

# %%
len(df)
# Out:
# 1856

# %%
# ========================================
#  1) SETUP: Google Drive & Installations
# ========================================
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# If you're in Google Colab or a Jupyter environment, run this cell to install/upgrade mediacloud
# !pip install --upgrade mediacloud
# Out:
# Collecting mediacloud
#   Downloading mediacloud-4.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests==2.* in /usr/local/lib/python3.11/dist-packages (from mediacloud) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.*->mediacloud) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.*->mediacloud) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.*->mediacloud) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.*->mediacloud) (2025.7.14)
# Downloading mediacloud-4.4.0-py3-none-any.whl (24 kB)
# Installing collected packages: mediacloud
# Successfully installed mediacloud-4.4.0

# %%
import logging
import datetime
import csv
import sys
import time
import mediacloud.api
import shutil  # for file copying

# ----------------------------------------------------------------------------
# CONFIGURATION
# ----------------------------------------------------------------------------

API_KEY = "0204d14c4f0a2d0f2a73238a48baafeeed105b5d"

# 1) Search Keyword
SEARCH_KEYWORD = "intelligence artificielle"
#intelligenza artificiale
#artificial intelligence
#هوش مصنوعی
#искусственный интеллект
#inteligência artificial
#künstliche intelligenz
#intelligence artificielle
#人工知能
#कृत्रिम होशियारी
#人工智能

# 2) Location (for reference in naming)
SEARCH_LOCATION = "france"

# 3) Overall Time Range
START_DATE_STR = "2024-06-01"
END_DATE_STR   = "2025-06-01"

# 4) Collection IDs for the given location
COLLECTION_IDS = [
    #34412372, #Italy National
    #38380117, #Italy State & Local
    #34412476, #UK National
    #38381111, #UK State & Local
    #34412284, #Iran - National
    #38380055, #Iran - State & Local
    #34412232, #Russia - National
    #38380780, #Russia - State & Local
    #34412257, #Brazil - National
    #38379250, #Brazil - State & Local
    #34412409, #Germany - National
    #38379816, #Germany - State & Local
    #34412056, #Japan - National
    #38380157, #Japan - State & Local
    #34412118, #India - National
    #38379954, #India - State & Local
    #34412234, #US - National
    #38379429, #US - State & Local
    #34412193, #China - National
    #38379438, #China - State & Local
    34412146, #France - National
    38379799, #France - State & Local
]



# United Kingdom - National
# https://search.mediacloud.org/collections/34412476

# United Kingdom - State & Local
# https://search.mediacloud.org/collections/38381111



# 5) Google Drive folder path
GDRIVE_PATH = "/content/drive/MyDrive/Mediacloud/France"

# Final CSV filename (for the entire range) with "mediacloud" in the name
FINAL_CSV_FILENAME = (
    f"{SEARCH_KEYWORD.lower().replace(' ', '_')}_"
    f"{SEARCH_LOCATION.lower()}_"
    f"{START_DATE_STR}_{END_DATE_STR}_mediacloud.csv"
)

# ----------------------------------------------------------------------------
# LOGGING SETUP
# ----------------------------------------------------------------------------

logging.basicConfig(
    stream=sys.stdout,
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# ----------------------------------------------------------------------------
# HELPER FUNCTIONS
# ----------------------------------------------------------------------------

def parse_date(date_str):
    """
    Convert 'YYYY-MM-DD' string to datetime.date.
    Raises ValueError if not correctly formatted.
    """
    return datetime.datetime.strptime(date_str, "%Y-%m-%d").date()

def last_day_of_month(any_date):
    """
    Given a datetime.date, return a date object representing
    the last day of that same month.
    """
    next_month = any_date.replace(day=28) + datetime.timedelta(days=4)
    return next_month - datetime.timedelta(days=next_month.day)

def generate_monthly_date_ranges(start_date_str, end_date_str):
    """
    Generate a list of (month_start_date, month_end_date) tuples
    covering each month from start_date to end_date inclusive.
    """
    start = parse_date(start_date_str)
    end = parse_date(end_date_str)

    monthly_chunks = []
    current_start = start

    while current_start <= end:
        # Last day of current_start's month
        current_end = last_day_of_month(current_start)
        # Do not exceed the overall end date
        if current_end > end:
            current_end = end

        monthly_chunks.append((current_start, current_end))

        # Move to the day after current_end
        next_month_start = current_end + datetime.timedelta(days=1)
        if next_month_start > end:
            break
        current_start = next_month_start

    return monthly_chunks

def generate_daily_date_ranges(start_date, end_date):
    """
    Generate a list of (day_start, day_end) tuples for each day between
    start_date and end_date (inclusive).
    In this case, day_start == day_end for daily intervals.
    """
    current_start = start_date
    daily_chunks = []

    while current_start <= end_date:
        # For a daily chunk, the start and end are the same date
        chunk_end = current_start
        daily_chunks.append((current_start, chunk_end))
        current_start = current_start + datetime.timedelta(days=1)

    return daily_chunks

def fetch_stories(mc_client, query, start_date, end_date, collection_ids):
    """
    Fetch all stories matching 'query' from 'start_date' to 'end_date' (inclusive),
    within any of the specified collection_ids.

    If more than 1000 stories are found for that day, it will fetch multiple pages,
    sleeping 55s between pages to respect rate limits. Returns a list of story dictionaries.
    """
    all_stories = []
    pagination_token = None

    while True:
        try:
            # Request up to 1000 stories per page
            page_stories, next_token = mc_client.story_list(
                query=query,
                start_date=start_date,
                end_date=end_date,
                collection_ids=collection_ids,
                pagination_token=pagination_token,
                page_size=1000
            )

            # Attach collection_ids to each story for reference
            for story in page_stories:
                story["collection_ids"] = collection_ids

            all_stories.extend(page_stories)

            # Print/log how many articles just fetched, total so far
            logging.info(
                f"Fetched {len(page_stories)} stories in this page; "
                f"{len(all_stories)} total so far (range {start_date} - {end_date})."
            )
            print(
                f"Fetched {len(page_stories)} stories in this request; "
                f"{len(all_stories)} total so far (range {start_date} - {end_date})."
            )

            # If there are no more pages, break
            if next_token is None:
                break

            # Pause for 55 seconds before fetching next page to respect rate limits
            logging.info("Pausing for 55 seconds to respect rate limits (multi-page).")
            print("Pausing for 55 seconds to respect rate limits (multi-page)...")
            time.sleep(55)

            # Prepare for next iteration
            pagination_token = next_token

        except Exception as e:
            logging.error(f"Error during API fetch (range {start_date} - {end_date}): {e}")
            break

    return all_stories

def save_stories_to_csv(stories, filename, query):
    """
    Save the story data to a CSV file, including a 'collection_ids' column and the 'query'.
    """
    fieldnames = [
        "stories_id",
        "title",
        "publish_date",
        "url",
        "language",
        "media_id",
        "media_name",
        "query",
        "collection_ids"
    ]

    try:
        with open(filename, mode="w", newline="", encoding="utf-8") as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()

            for story in stories:
                # Include the query in each row
                story["query"] = query
                row_data = {field: story.get(field, "") for field in fieldnames}
                writer.writerow(row_data)

        logging.info(f"Successfully wrote {len(stories)} stories to {filename}.")
    except Exception as e:
        logging.error(f"Error writing to CSV '{filename}': {e}")

def copy_to_drive(filename, destination_folder):
    """
    Attempt to copy the file from Colab's /content/ to the given Google Drive folder.
    """
    colab_path = f"/content/{filename}"
    try:
        shutil.copy(colab_path, destination_folder)
        logging.info(f"File '{filename}' copied to Google Drive at '{destination_folder}'.")
    except Exception as e:
        logging.error(f"Could not copy file '{filename}' to Google Drive: {e}")

# ----------------------------------------------------------------------------
# MAIN EXECUTION LOGIC
# ----------------------------------------------------------------------------

def main():
    # Initialize MediaCloud Search API client
    mc_client = mediacloud.api.SearchApi(API_KEY)

    # Confirm API connectivity
    try:
        mc_client.story_list(
            query="test",
            start_date=parse_date(START_DATE_STR),
            end_date=parse_date(START_DATE_STR),
            page_size=1
        )
        logging.info("MediaCloud API connection successful.")
    except Exception as e:
        logging.error(f"Could not validate MediaCloud API connection: {e}")
        return

    # Generate monthly chunks within the overall date range
    monthly_chunks = generate_monthly_date_ranges(START_DATE_STR, END_DATE_STR)
    logging.info(f"Will process data in {len(monthly_chunks)} monthly chunk(s).")

    all_stories = []

    # For each monthly chunk, we break it into daily intervals
    for (month_start, month_end) in monthly_chunks:
        logging.info(f"Processing month {month_start} to {month_end}...")

        monthly_stories = []
        daily_chunks = generate_daily_date_ranges(month_start, month_end)

        for (day_start, day_end) in daily_chunks:
            logging.info(f"  Fetching stories for {day_start} (one-day range)...")
            chunk_stories = fetch_stories(
                mc_client,
                SEARCH_KEYWORD,
                day_start,
                day_end,
                COLLECTION_IDS
            )
            monthly_stories.extend(chunk_stories)

            # Always pause 55 seconds after finishing the daily request,
            # regardless of how many pages were fetched for that day.
            logging.info(f"Pausing 55 seconds at the end of day {day_start}.")
            print(f"Pausing 55 seconds at the end of day {day_start}...")
            time.sleep(55)

        # Save monthly data to CSV
        # We'll name it "keyword_location_YYYY-MM_mediacloud.csv"
        month_label = f"{month_start.year}-{month_start.month:02d}"
        monthly_csv_filename = (
            f"{SEARCH_KEYWORD.lower().replace(' ', '_')}_"
            f"{SEARCH_LOCATION.lower()}_"
            f"{month_label}_mediacloud.csv"
        )

        save_stories_to_csv(monthly_stories, monthly_csv_filename, SEARCH_KEYWORD)
        # Copy monthly CSV to Google Drive for backup
        copy_to_drive(monthly_csv_filename, GDRIVE_PATH)

        # Add monthly stories to the grand total
        all_stories.extend(monthly_stories)

    # After all months are processed, save a final CSV for the entire range
    logging.info(f"Now saving final CSV for the entire range {START_DATE_STR} - {END_DATE_STR}...")
    save_stories_to_csv(all_stories, FINAL_CSV_FILENAME, SEARCH_KEYWORD)
    copy_to_drive(FINAL_CSV_FILENAME, GDRIVE_PATH)

    logging.info(
        f"Done! Retrieved {len(all_stories)} total stories "
        f"from {START_DATE_STR} to {END_DATE_STR}."
    )


# ----------------------------------------------------------------------------
# RUN
# ----------------------------------------------------------------------------

if __name__ == "__main__":
    main()
# Out:
# Fetched 12 stories in this request; 12 total so far (range 2024-06-01 - 2024-06-01).
# Pausing 55 seconds at the end of day 2024-06-01...
# ERROR:root:Error during API fetch (range 2024-06-02 - 2024-06-02): API Server Error 403. Params: {'start': '2024-06-02', 'end': '2024-06-02', 'q': 'intelligence artificielle', 'platform': 'onlinenews-mediacloud', 'cs': ('34412146,38379799',), 'page_size': 1000}
# Pausing 55 seconds at the end of day 2024-06-02...
# Fetched 24 stories in this request; 24 total so far (range 2024-06-03 - 2024-06-03).
# Pausing 55 seconds at the end of day 2024-06-03...
# Fetched 49 stories in this request; 49 total so far (range 2024-06-04 - 2024-06-04).
# Pausing 55 seconds at the end of day 2024-06-04...
# Fetched 30 stories in this request; 30 total so far (range 2024-06-05 - 2024-06-05).
# Pausing 55 seconds at the end of day 2024-06-05...
# Fetched 24 stories in this request; 24 total so far (range 2024-06-06 - 2024-06-06).
# Pausing 55 seconds at the end of day 2024-06-06...
# Fetched 18 stories in this request; 18 total so far (range 2024-06-07 - 2024-06-07).
# Pausing 55 seconds at the end of day 2024-06-07...
# Fetched 15 stories in this request; 15 total so far (range 2024-06-08 - 2024-06-08).
# Pausing 55 seconds at the end of day 2024-06-08...
# Fetched 6 stories in this request; 6 total so far (range 2024-06-09 - 2024-06-09).
# Pausing 55 seconds at the end of day 2024-06-09...
# Fetched 34 stories in this request; 34 total so far (range 2024-06-10 - 2024-06-10).
# Pausing 55 seconds at the end of day 2024-06-10...
# Fetched 53 stories in this request; 53 total so far (range 2024-06-11 - 2024-06-11).
# Pausing 55 seconds at the end of day 2024-06-11...
# Fetched 37 stories in this request; 37 total so far (range 2024-06-12 - 2024-06-12).
# Pausing 55 seconds at the end of day 2024-06-12...
# Fetched 27 stories in this request; 27 total so far (range 2024-06-13 - 2024-06-13).
# Pausing 55 seconds at the end of day 2024-06-13...
# Fetched 20 stories in this request; 20 total so far (range 2024-06-14 - 2024-06-14).
# Pausing 55 seconds at the end of day 2024-06-14...
# Fetched 12 stories in this request; 12 total so far (range 2024-06-15 - 2024-06-15).
# Pausing 55 seconds at the end of day 2024-06-15...
# Fetched 11 stories in this request; 11 total so far (range 2024-06-16 - 2024-06-16).
# Pausing 55 seconds at the end of day 2024-06-16...
# Fetched 22 stories in this request; 22 total so far (range 2024-06-17 - 2024-06-17).
# Pausing 55 seconds at the end of day 2024-06-17...
# Fetched 20 stories in this request; 20 total so far (range 2024-06-18 - 2024-06-18).
# Pausing 55 seconds at the end of day 2024-08-05...
# Fetched 13 stories in this request; 13 total so far (range 2024-08-06 - 2024-08-06).
# Pausing 55 seconds at the end of day 2024-08-06...
# Fetched 8 stories in this request; 8 total so far (range 2024-08-07 - 2024-08-07).
# Pausing 55 seconds at the end of day 2024-08-07...
# Fetched 9 stories in this request; 9 total so far (range 2024-08-08 - 2024-08-08).
# Pausing 55 seconds at the end of day 2024-08-08...
# Fetched 20 stories in this request; 20 total so far (range 2024-08-09 - 2024-08-09).
# Pausing 55 seconds at the end of day 2024-08-09...
# Fetched 3 stories in this request; 3 total so far (range 2024-08-10 - 2024-08-10).
# Pausing 55 seconds at the end of day 2024-08-10...
# Fetched 5 stories in this request; 5 total so far (range 2024-08-11 - 2024-08-11).
# Pausing 55 seconds at the end of day 2024-08-11...
# Fetched 14 stories in this request; 14 total so far (range 2024-08-12 - 2024-08-12).
# Pausing 55 seconds at the end of day 2024-08-12...
# Fetched 15 stories in this request; 15 total so far (range 2024-08-13 - 2024-08-13).
# Pausing 55 seconds at the end of day 2024-08-13...
# Fetched 20 stories in this request; 20 total so far (range 2024-08-14 - 2024-08-14).
# Pausing 55 seconds at the end of day 2024-08-14...
# Fetched 12 stories in this request; 12 total so far (range 2024-08-15 - 2024-08-15).
# Pausing 55 seconds at the end of day 2024-08-15...
# Fetched 11 stories in this request; 11 total so far (range 2024-08-16 - 2024-08-16).
# Pausing 55 seconds at the end of day 2024-08-16...
# Fetched 3 stories in this request; 3 total so far (range 2024-08-17 - 2024-08-17).
# Pausing 55 seconds at the end of day 2024-08-17...
# Fetched 8 stories in this request; 8 total so far (range 2024-08-18 - 2024-08-18).
# Pausing 55 seconds at the end of day 2024-08-18...
# Fetched 12 stories in this request; 12 total so far (range 2024-08-19 - 2024-08-19).
# Pausing 55 seconds at the end of day 2024-08-19...
# Fetched 14 stories in this request; 14 total so far (range 2024-08-20 - 2024-08-20).
# Pausing 55 seconds at the end of day 2024-08-20...
# Fetched 7 stories in this request; 7 total so far (range 2024-08-21 - 2024-08-21).
# Pausing 55 seconds at the end of day 2024-08-21...
# Fetched 9 stories in this request; 9 total so far (range 2024-08-22 - 2024-08-22).
# Pausing 55 seconds at the end of day 2024-08-22...
# Fetched 11 stories in this request; 11 total so far (range 2024-08-23 - 2024-08-23).
# Pausing 55 seconds at the end of day 2024-08-23...
# Fetched 9 stories in this request; 9 total so far (range 2024-08-24 - 2024-08-24).
# Pausing 55 seconds at the end of day 2024-08-24...
# Fetched 5 stories in this request; 5 total so far (range 2024-08-25 - 2024-08-25).
# Pausing 55 seconds at the end of day 2024-08-25...
# Fetched 12 stories in this request; 12 total so far (range 2024-08-26 - 2024-08-26).
# Pausing 55 seconds at the end of day 2024-08-26...
# Fetched 16 stories in this request; 16 total so far (range 2024-08-27 - 2024-08-27).
# Pausing 55 seconds at the end of day 2024-08-27...
# Fetched 21 stories in this request; 21 total so far (range 2024-08-28 - 2024-08-28).
# Pausing 55 seconds at the end of day 2024-08-28...
# Fetched 16 stories in this request; 16 total so far (range 2024-08-29 - 2024-08-29).
# Pausing 55 seconds at the end of day 2024-08-29...
# Fetched 17 stories in this request; 17 total so far (range 2024-08-30 - 2024-08-30).
# Pausing 55 seconds at the end of day 2024-08-30...
# Fetched 2 stories in this request; 2 total so far (range 2024-08-31 - 2024-08-31).
# Pausing 55 seconds at the end of day 2024-08-31...
# Fetched 6 stories in this request; 6 total so far (range 2024-09-01 - 2024-09-01).
# Pausing 55 seconds at the end of day 2024-09-01...
# Fetched 13 stories in this request; 13 total so far (range 2024-09-02 - 2024-09-02).
# Pausing 55 seconds at the end of day 2024-09-02...
# Fetched 7 stories in this request; 7 total so far (range 2024-09-03 - 2024-09-03).
# Pausing 55 seconds at the end of day 2024-09-03...
# Fetched 14 stories in this request; 14 total so far (range 2024-09-04 - 2024-09-04).
# Pausing 55 seconds at the end of day 2024-09-04...
# Fetched 7 stories in this request; 7 total so far (range 2024-09-05 - 2024-09-05).
# Pausing 55 seconds at the end of day 2024-09-05...
# Fetched 10 stories in this request; 10 total so far (range 2024-09-06 - 2024-09-06).
# Pausing 55 seconds at the end of day 2024-09-06...
# Fetched 8 stories in this request; 8 total so far (range 2024-09-07 - 2024-09-07).
# Pausing 55 seconds at the end of day 2024-09-07...
# Fetched 7 stories in this request; 7 total so far (range 2024-09-08 - 2024-09-08).
# Pausing 55 seconds at the end of day 2024-09-08...
# Fetched 52 stories in this request; 52 total so far (range 2024-09-09 - 2024-09-09).
# Pausing 55 seconds at the end of day 2024-09-09...
# Fetched 56 stories in this request; 56 total so far (range 2024-09-10 - 2024-09-10).
# Pausing 55 seconds at the end of day 2024-09-10...
# Fetched 27 stories in this request; 27 total so far (range 2024-09-11 - 2024-09-11).
# Pausing 55 seconds at the end of day 2024-09-11...
# Fetched 17 stories in this request; 17 total so far (range 2024-09-12 - 2024-09-12).
# Pausing 55 seconds at the end of day 2024-09-12...
# Fetched 20 stories in this request; 20 total so far (range 2024-09-13 - 2024-09-13).
# Pausing 55 seconds at the end of day 2024-09-13...
# Fetched 9 stories in this request; 9 total so far (range 2024-09-14 - 2024-09-14).
# Pausing 55 seconds at the end of day 2024-09-14...
# Fetched 23 stories in this request; 23 total so far (range 2024-09-15 - 2024-09-15).
# Pausing 55 seconds at the end of day 2024-09-15...
# Fetched 16 stories in this request; 16 total so far (range 2024-09-16 - 2024-09-16).
# Pausing 55 seconds at the end of day 2024-09-16...
# Fetched 18 stories in this request; 18 total so far (range 2024-09-17 - 2024-09-17).
# Pausing 55 seconds at the end of day 2024-09-17...
# Fetched 18 stories in this request; 18 total so far (range 2024-09-18 - 2024-09-18).
# Pausing 55 seconds at the end of day 2024-09-18...
# Fetched 34 stories in this request; 34 total so far (range 2024-09-19 - 2024-09-19).
# Pausing 55 seconds at the end of day 2024-09-19...
# Fetched 10 stories in this request; 10 total so far (range 2024-09-20 - 2024-09-20).
# Pausing 55 seconds at the end of day 2024-09-20...
# Fetched 10 stories in this request; 10 total so far (range 2024-09-21 - 2024-09-21).
# Pausing 55 seconds at the end of day 2024-09-21...
# Fetched 5 stories in this request; 5 total so far (range 2024-09-22 - 2024-09-22).
# Pausing 55 seconds at the end of day 2024-09-22...
# Fetched 16 stories in this request; 16 total so far (range 2024-09-23 - 2024-09-23).
# Pausing 55 seconds at the end of day 2024-09-23...
# Fetched 18 stories in this request; 18 total so far (range 2024-09-24 - 2024-09-24).
# Pausing 55 seconds at the end of day 2024-09-24...
# Fetched 11 stories in this request; 11 total so far (range 2024-09-25 - 2024-09-25).
# Pausing 55 seconds at the end of day 2024-09-25...
# Fetched 40 stories in this request; 40 total so far (range 2024-09-26 - 2024-09-26).
# Pausing 55 seconds at the end of day 2024-09-26...
# Fetched 24 stories in this request; 24 total so far (range 2024-09-27 - 2024-09-27).
# Pausing 55 seconds at the end of day 2024-09-27...
# Fetched 5 stories in this request; 5 total so far (range 2024-09-28 - 2024-09-28).
# Pausing 55 seconds at the end of day 2024-09-28...
# Fetched 7 stories in this request; 7 total so far (range 2024-09-29 - 2024-09-29).
# Pausing 55 seconds at the end of day 2024-09-29...
# Fetched 20 stories in this request; 20 total so far (range 2024-09-30 - 2024-09-30).
# Pausing 55 seconds at the end of day 2024-09-30...
# Fetched 27 stories in this request; 27 total so far (range 2024-10-01 - 2024-10-01).
# Pausing 55 seconds at the end of day 2024-10-01...
# Fetched 45 stories in this request; 45 total so far (range 2024-10-02 - 2024-10-02).
# Pausing 55 seconds at the end of day 2024-10-02...
# Fetched 18 stories in this request; 18 total so far (range 2024-10-03 - 2024-10-03).
# Pausing 55 seconds at the end of day 2024-10-03...
# Fetched 19 stories in this request; 19 total so far (range 2024-10-04 - 2024-10-04).
# Pausing 55 seconds at the end of day 2024-10-04...
# Fetched 30 stories in this request; 30 total so far (range 2024-10-05 - 2024-10-05).
# Pausing 55 seconds at the end of day 2024-10-05...
# Fetched 10 stories in this request; 10 total so far (range 2024-10-06 - 2024-10-06).
# Pausing 55 seconds at the end of day 2024-10-06...
# Fetched 13 stories in this request; 13 total so far (range 2024-10-07 - 2024-10-07).
# Pausing 55 seconds at the end of day 2024-10-07...
# Fetched 24 stories in this request; 24 total so far (range 2024-10-08 - 2024-10-08).
# Pausing 55 seconds at the end of day 2024-10-08...
# Fetched 28 stories in this request; 28 total so far (range 2024-10-09 - 2024-10-09).
# Pausing 55 seconds at the end of day 2024-10-09...
# Fetched 33 stories in this request; 33 total so far (range 2024-10-10 - 2024-10-10).
# Pausing 55 seconds at the end of day 2024-10-10...
# Fetched 27 stories in this request; 27 total so far (range 2024-10-11 - 2024-10-11).
# Pausing 55 seconds at the end of day 2024-10-11...
# Fetched 7 stories in this request; 7 total so far (range 2024-10-12 - 2024-10-12).
# Pausing 55 seconds at the end of day 2024-10-12...
# Fetched 6 stories in this request; 6 total so far (range 2024-10-13 - 2024-10-13).
# Pausing 55 seconds at the end of day 2024-10-13...
# Fetched 16 stories in this request; 16 total so far (range 2024-10-14 - 2024-10-14).
# Pausing 55 seconds at the end of day 2024-10-14...
# Fetched 30 stories in this request; 30 total so far (range 2024-10-15 - 2024-10-15).
# Pausing 55 seconds at the end of day 2024-10-15...
# Fetched 16 stories in this request; 16 total so far (range 2024-12-27 - 2024-12-27).
# Pausing 55 seconds at the end of day 2024-12-27...
# Fetched 5 stories in this request; 5 total so far (range 2024-12-28 - 2024-12-28).
# Pausing 55 seconds at the end of day 2024-12-28...
# Fetched 6 stories in this request; 6 total so far (range 2024-12-29 - 2024-12-29).
# Pausing 55 seconds at the end of day 2024-12-29...
# Fetched 12 stories in this request; 12 total so far (range 2024-12-30 - 2024-12-30).
# Pausing 55 seconds at the end of day 2024-12-30...
# Fetched 11 stories in this request; 11 total so far (range 2024-12-31 - 2024-12-31).
# Pausing 55 seconds at the end of day 2024-12-31...
# Fetched 11 stories in this request; 11 total so far (range 2025-01-01 - 2025-01-01).
# Pausing 55 seconds at the end of day 2025-01-01...
# Fetched 4 stories in this request; 4 total so far (range 2025-01-02 - 2025-01-02).
# Pausing 55 seconds at the end of day 2025-01-02...
# Fetched 14 stories in this request; 14 total so far (range 2025-01-03 - 2025-01-03).
# Pausing 55 seconds at the end of day 2025-01-03...
# Fetched 8 stories in this request; 8 total so far (range 2025-01-04 - 2025-01-04).
# Pausing 55 seconds at the end of day 2025-01-04...
# Fetched 8 stories in this request; 8 total so far (range 2025-01-05 - 2025-01-05).
# Pausing 55 seconds at the end of day 2025-01-05...
# Fetched 15 stories in this request; 15 total so far (range 2025-01-06 - 2025-01-06).
# Pausing 55 seconds at the end of day 2025-01-06...
# Fetched 35 stories in this request; 35 total so far (range 2025-01-07 - 2025-01-07).
# Pausing 55 seconds at the end of day 2025-01-07...
# Fetched 37 stories in this request; 37 total so far (range 2025-01-08 - 2025-01-08).
# Pausing 55 seconds at the end of day 2025-01-08...
# Fetched 14 stories in this request; 14 total so far (range 2025-01-09 - 2025-01-09).
# Pausing 55 seconds at the end of day 2025-01-09...
# Fetched 22 stories in this request; 22 total so far (range 2025-01-10 - 2025-01-10).
# Pausing 55 seconds at the end of day 2025-01-10...
# Fetched 17 stories in this request; 17 total so far (range 2025-01-11 - 2025-01-11).
# Pausing 55 seconds at the end of day 2025-01-11...
# Fetched 12 stories in this request; 12 total so far (range 2025-01-12 - 2025-01-12).
# Pausing 55 seconds at the end of day 2025-01-12...
# Fetched 20 stories in this request; 20 total so far (range 2025-01-13 - 2025-01-13).
# Pausing 55 seconds at the end of day 2025-01-13...
# Fetched 18 stories in this request; 18 total so far (range 2025-01-14 - 2025-01-14).
# Pausing 55 seconds at the end of day 2025-01-14...
# Fetched 22 stories in this request; 22 total so far (range 2025-01-15 - 2025-01-15).
# Pausing 55 seconds at the end of day 2025-01-15...
# Fetched 25 stories in this request; 25 total so far (range 2025-01-16 - 2025-01-16).
# Pausing 55 seconds at the end of day 2025-01-16...
# Fetched 15 stories in this request; 15 total so far (range 2025-01-17 - 2025-01-17).
# Pausing 55 seconds at the end of day 2025-01-17...
# Fetched 11 stories in this request; 11 total so far (range 2025-01-18 - 2025-01-18).
# Pausing 55 seconds at the end of day 2025-01-18...
# Fetched 6 stories in this request; 6 total so far (range 2025-01-19 - 2025-01-19).
# Pausing 55 seconds at the end of day 2025-01-19...
# Pausing 55 seconds at the end of day 2025-03-08...
# Fetched 15 stories in this request; 15 total so far (range 2025-03-09 - 2025-03-09).
# Pausing 55 seconds at the end of day 2025-03-09...
# Fetched 32 stories in this request; 32 total so far (range 2025-03-10 - 2025-03-10).
# Pausing 55 seconds at the end of day 2025-03-10...
# Fetched 35 stories in this request; 35 total so far (range 2025-03-11 - 2025-03-11).
# Pausing 55 seconds at the end of day 2025-03-11...
# Fetched 43 stories in this request; 43 total so far (range 2025-03-12 - 2025-03-12).
# Pausing 55 seconds at the end of day 2025-03-12...
# Fetched 19 stories in this request; 19 total so far (range 2025-03-13 - 2025-03-13).
# Pausing 55 seconds at the end of day 2025-03-13...
# Fetched 26 stories in this request; 26 total so far (range 2025-03-14 - 2025-03-14).
# Pausing 55 seconds at the end of day 2025-03-14...
# Fetched 10 stories in this request; 10 total so far (range 2025-03-15 - 2025-03-15).
# Pausing 55 seconds at the end of day 2025-03-15...
# Fetched 21 stories in this request; 21 total so far (range 2025-03-16 - 2025-03-16).
# Pausing 55 seconds at the end of day 2025-03-16...
# Fetched 33 stories in this request; 33 total so far (range 2025-03-17 - 2025-03-17).
# Pausing 55 seconds at the end of day 2025-03-17...
# Fetched 29 stories in this request; 29 total so far (range 2025-03-18 - 2025-03-18).
# Pausing 55 seconds at the end of day 2025-03-18...
# Fetched 29 stories in this request; 29 total so far (range 2025-03-19 - 2025-03-19).
# Pausing 55 seconds at the end of day 2025-03-19...
# Fetched 38 stories in this request; 38 total so far (range 2025-03-20 - 2025-03-20).
# Pausing 55 seconds at the end of day 2025-03-20...
# Fetched 19 stories in this request; 19 total so far (range 2025-03-21 - 2025-03-21).
# Pausing 55 seconds at the end of day 2025-03-21...
# Fetched 31 stories in this request; 31 total so far (range 2025-03-22 - 2025-03-22).
# Pausing 55 seconds at the end of day 2025-03-22...
# Fetched 13 stories in this request; 13 total so far (range 2025-03-23 - 2025-03-23).
# Pausing 55 seconds at the end of day 2025-03-23...
# Fetched 23 stories in this request; 23 total so far (range 2025-03-24 - 2025-03-24).
# Pausing 55 seconds at the end of day 2025-03-24...
# Fetched 29 stories in this request; 29 total so far (range 2025-03-25 - 2025-03-25).
# Pausing 55 seconds at the end of day 2025-03-25...
# Fetched 45 stories in this request; 45 total so far (range 2025-03-26 - 2025-03-26).
# Pausing 55 seconds at the end of day 2025-03-26...
# Fetched 26 stories in this request; 26 total so far (range 2025-03-27 - 2025-03-27).
# Pausing 55 seconds at the end of day 2025-03-27...
# Fetched 20 stories in this request; 20 total so far (range 2025-03-28 - 2025-03-28).
# Pausing 55 seconds at the end of day 2025-03-28...
# Fetched 18 stories in this request; 18 total so far (range 2025-03-29 - 2025-03-29).
# Pausing 55 seconds at the end of day 2025-03-29...
# Fetched 15 stories in this request; 15 total so far (range 2025-03-30 - 2025-03-30).
# Pausing 55 seconds at the end of day 2025-03-30...
# Fetched 33 stories in this request; 33 total so far (range 2025-03-31 - 2025-03-31).
# Pausing 55 seconds at the end of day 2025-03-31...
# Fetched 29 stories in this request; 29 total so far (range 2025-04-01 - 2025-04-01).
# Pausing 55 seconds at the end of day 2025-04-25...
# Fetched 16 stories in this request; 16 total so far (range 2025-04-26 - 2025-04-26).
# Pausing 55 seconds at the end of day 2025-04-26...
# Fetched 19 stories in this request; 19 total so far (range 2025-04-27 - 2025-04-27).
# Pausing 55 seconds at the end of day 2025-04-27...
# Fetched 18 stories in this request; 18 total so far (range 2025-04-28 - 2025-04-28).
# Pausing 55 seconds at the end of day 2025-04-28...
# Fetched 48 stories in this request; 48 total so far (range 2025-04-29 - 2025-04-29).
# Pausing 55 seconds at the end of day 2025-04-29...
# Fetched 34 stories in this request; 34 total so far (range 2025-04-30 - 2025-04-30).
# Pausing 55 seconds at the end of day 2025-04-30...
# Fetched 13 stories in this request; 13 total so far (range 2025-05-01 - 2025-05-01).
# Pausing 55 seconds at the end of day 2025-05-01...
# Fetched 20 stories in this request; 20 total so far (range 2025-05-02 - 2025-05-02).
# Pausing 55 seconds at the end of day 2025-05-02...
# Fetched 18 stories in this request; 18 total so far (range 2025-05-03 - 2025-05-03).
# Pausing 55 seconds at the end of day 2025-05-03...
# Fetched 14 stories in this request; 14 total so far (range 2025-05-04 - 2025-05-04).
# Pausing 55 seconds at the end of day 2025-05-04...
# Fetched 33 stories in this request; 33 total so far (range 2025-05-05 - 2025-05-05).
# Pausing 55 seconds at the end of day 2025-05-05...
# Fetched 31 stories in this request; 31 total so far (range 2025-05-06 - 2025-05-06).
# Pausing 55 seconds at the end of day 2025-05-06...
# Fetched 39 stories in this request; 39 total so far (range 2025-05-07 - 2025-05-07).
# Pausing 55 seconds at the end of day 2025-05-07...
# Fetched 11 stories in this request; 11 total so far (range 2025-05-08 - 2025-05-08).
# Pausing 55 seconds at the end of day 2025-05-08...
# Fetched 30 stories in this request; 30 total so far (range 2025-05-09 - 2025-05-09).
# Pausing 55 seconds at the end of day 2025-05-09...
# Fetched 14 stories in this request; 14 total so far (range 2025-05-10 - 2025-05-10).
# Pausing 55 seconds at the end of day 2025-05-10...
# Fetched 15 stories in this request; 15 total so far (range 2025-05-11 - 2025-05-11).
# Pausing 55 seconds at the end of day 2025-05-11...
# Fetched 25 stories in this request; 25 total so far (range 2025-05-12 - 2025-05-12).
# Pausing 55 seconds at the end of day 2025-05-12...
# Fetched 39 stories in this request; 39 total so far (range 2025-05-13 - 2025-05-13).
# Pausing 55 seconds at the end of day 2025-05-13...
# Fetched 57 stories in this request; 57 total so far (range 2025-05-14 - 2025-05-14).
# Pausing 55 seconds at the end of day 2025-05-14...
# Fetched 36 stories in this request; 36 total so far (range 2025-05-15 - 2025-05-15).
# Pausing 55 seconds at the end of day 2025-05-15...
# Fetched 35 stories in this request; 35 total so far (range 2025-05-16 - 2025-05-16).
# Pausing 55 seconds at the end of day 2025-05-16...
# Fetched 13 stories in this request; 13 total so far (range 2025-05-17 - 2025-05-17).
# Pausing 55 seconds at the end of day 2025-05-17...
# Fetched 20 stories in this request; 20 total so far (range 2025-05-18 - 2025-05-18).
# Pausing 55 seconds at the end of day 2025-05-18...
# Fetched 25 stories in this request; 25 total so far (range 2025-05-19 - 2025-05-19).
# Pausing 55 seconds at the end of day 2025-05-19...
# Fetched 37 stories in this request; 37 total so far (range 2025-05-20 - 2025-05-20).
# Pausing 55 seconds at the end of day 2025-05-20...
# Fetched 44 stories in this request; 44 total so far (range 2025-05-21 - 2025-05-21).
# Pausing 55 seconds at the end of day 2025-05-21...
# Fetched 25 stories in this request; 25 total so far (range 2025-05-22 - 2025-05-22).
# Pausing 55 seconds at the end of day 2025-05-22...
# Fetched 33 stories in this request; 33 total so far (range 2025-05-23 - 2025-05-23).
# Pausing 55 seconds at the end of day 2025-05-23...
# Fetched 15 stories in this request; 15 total so far (range 2025-05-24 - 2025-05-24).
# Pausing 55 seconds at the end of day 2025-05-24...
# Fetched 10 stories in this request; 10 total so far (range 2025-05-25 - 2025-05-25).
# Pausing 55 seconds at the end of day 2025-05-25...
# Fetched 38 stories in this request; 38 total so far (range 2025-05-26 - 2025-05-26).
# Pausing 55 seconds at the end of day 2025-05-26...
# Fetched 41 stories in this request; 41 total so far (range 2025-05-27 - 2025-05-27).
# Pausing 55 seconds at the end of day 2025-05-27...
# Fetched 25 stories in this request; 25 total so far (range 2025-05-28 - 2025-05-28).
# Pausing 55 seconds at the end of day 2025-05-28...
# Fetched 41 stories in this request; 41 total so far (range 2025-05-29 - 2025-05-29).
# Pausing 55 seconds at the end of day 2025-05-29...
# Fetched 18 stories in this request; 18 total so far (range 2025-05-30 - 2025-05-30).
# Pausing 55 seconds at the end of day 2025-05-30...
# Fetched 16 stories in this request; 16 total so far (range 2025-05-31 - 2025-05-31).
# Pausing 55 seconds at the end of day 2025-05-31...
# Fetched 14 stories in this request; 14 total so far (range 2025-06-01 - 2025-06-01).
# Pausing 55 seconds at the end of day 2025-06-01...

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Mediacloud/France/intelligence_artificielle_france_2024-06-01_2025-06-01_mediacloud.csv')
df.head()
# Out:
#    stories_id                                              title publish_date  \
# 0         NaN  Paul Jorion, psychanalyste – Mise à jour – Blo...   2024-06-01
# 1         NaN  Les carnets du psychanalyste – Veiller – Blog ...   2024-06-01
# 2         NaN             L'IA se prépare pour aller à la guerre   2024-06-01
# 3         NaN  N'attendez pas pour profiter de cette offre su...   2024-06-01
# 4         NaN  Ce smartphone Xiaomi à moins de 110 euros fait...   2024-06-01
#
#                                                  url language  media_id  \
# 0  https://www.pauljorion.com/blog/2024/06/01/pau...       fr       NaN
# 1  https://www.pauljorion.com/blog/2024/06/01/les...       fr       NaN
# 2  https://www.sciencesetavenir.fr/high-tech/inte...       fr       NaN
# 3  https://www.bfmtv.com/tech/bons-plans/n-attend...       fr       NaN
# 4  https://www.bfmtv.com/tech/bons-plans/ce-smart...       fr       NaN
#
#             media_name                      query        collection_ids
# 0       pauljorion.com  intelligence artificielle  [34412146, 38379799]
# 1       pauljorion.com  intelligence artificielle  [34412146, 38379799]
# 2  sciencesetavenir.fr  intelligence artificielle  [34412146, 38379799]
# 3            bfmtv.com  intelligence artificielle  [34412146, 38379799]
# 4            bfmtv.com  intelligence artificielle  [34412146, 38379799]

# %%
len(df)
# Out:
# 8172
